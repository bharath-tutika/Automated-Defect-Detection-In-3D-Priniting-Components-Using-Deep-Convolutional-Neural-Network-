# %% [markdown]
# # Notebook 03: YOLO Model Training
#
# This notebook demonstrates training an Ultralytics YOLO object detector on the custom 3D printing defect dataset.

# %%
from pathlib import Path
import torch
from ultralytics import YOLO

BASE_DIR = Path("..").resolve()
DATA_YAML = str(BASE_DIR / "dataset" / "data.yaml")

device = "0" if torch.cuda.is_available() else "cpu"
print(f"Using compute device: {device}")

# Initialize base model
model = YOLO("yolov8n.pt")
print("Base YOLO model initialized.")

# %%
# Run Training Loop (Example: 25 epochs)
# results = model.train(
#     data=DATA_YAML,
#     epochs=25,
#     imgsz=640,
#     batch=16,
#     device=device,
#     project=str(BASE_DIR / "training" / "results"),
#     name="notebook_run"
# )
